# %%
import pandas as pd
import numpy as np
import tqdm

# %%
best_without_outlier_sub = pd.read_csv("去除异常值_sub/submission_1.5540623551602637.csv")

# %%
best_classifer_model_sub = pd.read_csv("class_sub/submission_0.0438382729072731.csv")

# %%
best_classifer_model_sub.sort_values(by='target',ascending = False,inplace=True)

# %%
best_classifer_model_sub.head(20)
# Out:
#                 card_id    target
# 78078   C_ID_922f9c5ea6  0.663129
# 103851  C_ID_877b879853  0.631387
# 59178   C_ID_a4dfae60b0  0.573193
# 20556   C_ID_aae50409e7  0.550545
# 48908   C_ID_eff57c75a3  0.549016
# 32446   C_ID_ac114ef831  0.547913
# 70804   C_ID_833aa2f7af  0.543521
# 76013   C_ID_1afd4a6a1f  0.535378
# 104991  C_ID_86ddafb51c  0.534246
# 111099  C_ID_601974ff16  0.525648
# 2726    C_ID_1edbae8171  0.523336
# 7750    C_ID_a74b12dcf8  0.519379
# 77945   C_ID_6ab591cf62  0.518585
# 27314   C_ID_7f5f950342  0.507279
# 26864   C_ID_e7c702e96f  0.490761
# 18533   C_ID_f06cab397a  0.488978
# 93124   C_ID_efbf650295  0.486748
# 114106  C_ID_e54aeb08f7  0.484745
# 64852   C_ID_3ad8cfa863  0.481029
# 115682  C_ID_099d9774e2  0.478617

# %%
123623*0.0106
# Out:
# 1310.4038

# %%
#In case missing some predictable outlier, we choose top 25000 with highest outliers likelyhood.
outlier_id = pd.DataFrame(best_classifer_model_sub.sort_values(by='target',ascending = False).head(25000)['card_id'])

# %%
outlier_id
# Out:
#                 card_id
# 78078   C_ID_922f9c5ea6
# 103851  C_ID_877b879853
# 59178   C_ID_a4dfae60b0
# 20556   C_ID_aae50409e7
# 48908   C_ID_eff57c75a3
# 32446   C_ID_ac114ef831
# 70804   C_ID_833aa2f7af
# 76013   C_ID_1afd4a6a1f
# 104991  C_ID_86ddafb51c
# 111099  C_ID_601974ff16
# 2726    C_ID_1edbae8171
# 7750    C_ID_a74b12dcf8
# 77945   C_ID_6ab591cf62
# 27314   C_ID_7f5f950342
# 26864   C_ID_e7c702e96f
# 18533   C_ID_f06cab397a
# 93124   C_ID_efbf650295
# 114106  C_ID_e54aeb08f7
# 64852   C_ID_3ad8cfa863
# 115682  C_ID_099d9774e2
# 27436   C_ID_493de71141
# 11757   C_ID_da19d1dac9
# 108079  C_ID_84e90acaf9
# 30248   C_ID_65a0e440f8
# 54793   C_ID_761c27a0f2
# 67665   C_ID_3b5972c942
# 41138   C_ID_d706b6696a
# 63477   C_ID_77cafbf835
# 107752  C_ID_0c22eb865e
# 96996   C_ID_7c382e6fde
# ...                 ...
# 93725   C_ID_81718d47b1
# 84635   C_ID_fb7c18d7f8
# 35245   C_ID_27edb90dbf
# 32617   C_ID_47afe1cf50
# 39007   C_ID_1b141c0f57
# 100272  C_ID_694d7b9994
# 107510  C_ID_d46c739986
# 98143   C_ID_5c2b3e0cae
# 100735  C_ID_1ab62c49bf
# 8273    C_ID_2db1edfd42
# 107073  C_ID_9bcdfbdf78
# 81541   C_ID_962bba6670
# 114314  C_ID_1358629a14
# 86076   C_ID_675d418127
# 52527   C_ID_5d6197fb56
# 116838  C_ID_d0da867cbb
# 88447   C_ID_e2094a7a09
# 122489  C_ID_d179b53e76
# 97241   C_ID_5d3a956fa4
# 118754  C_ID_5062f4ef0b
# 1248    C_ID_65c2337371
# 41427   C_ID_e06c7cd05b
# 47617   C_ID_4d9fdc4110
# 9623    C_ID_d257ec5008
# 68265   C_ID_20cbad48d3
# 48395   C_ID_3cea0ac2e5
# 61813   C_ID_2d3bd00cc1
# 120727  C_ID_af964136bc
# 3325    C_ID_031308b90e
# 60498   C_ID_747cee53b8
#
# [25000 rows x 1 columns]

# %%
best_submission = pd.read_csv('with_out_pro_lb670.csv')

# %%
most_likely_liers = best_submission.merge(outlier_id,how='right')
most_likely_liers.head()
# Out:
#            card_id    target
# 0  C_ID_0ab67a22ab -2.408253
# 1  C_ID_6d8dba8475 -0.852972
# 2  C_ID_7f1041e8e1 -8.599524
# 3  C_ID_22e4a47c72 -0.224197
# 4  C_ID_b54cfad8b2 -1.138913

# %%
eda_most_like =  most_likely_liers.copy()
tmp = best_classifer_model_sub.copy()
tmp.rename(columns={'target':'prob'},inplace=True)
eda_most_like = pd.merge(eda_most_like,tmp,how='left',on='card_id')

# %%
eda_most_like.sort_values(by='prob',ascending = False,inplace=True)
eda_most_like.head(50)
# Out:
#                card_id     target      prob
# 15653  C_ID_922f9c5ea6 -25.277260  0.663129
# 20967  C_ID_877b879853 -25.719241  0.631387
# 11831  C_ID_a4dfae60b0 -17.963146  0.573193
# 4119   C_ID_aae50409e7 -21.257249  0.550545
# 9772   C_ID_eff57c75a3 -17.211415  0.549016
# 6507   C_ID_ac114ef831 -23.053265  0.547913
# 14202  C_ID_833aa2f7af -16.144493  0.543521
# 15233  C_ID_1afd4a6a1f -16.375920  0.535378
# 21229  C_ID_86ddafb51c -23.051428  0.534246
# 22464  C_ID_601974ff16 -19.149264  0.525648
# 529    C_ID_1edbae8171 -18.700268  0.523336
# 1532   C_ID_a74b12dcf8 -24.703352  0.519379
# 15630  C_ID_6ab591cf62 -21.299295  0.518585
# 5482   C_ID_7f5f950342 -16.180241  0.507279
# 5394   C_ID_e7c702e96f -16.308089  0.490761
# 3724   C_ID_f06cab397a -14.232203  0.488978
# 18762  C_ID_efbf650295 -16.853801  0.486748
# 23090  C_ID_e54aeb08f7 -22.065716  0.484745
# 13009  C_ID_3ad8cfa863 -16.478209  0.481029
# 23398  C_ID_099d9774e2 -19.690900  0.478617
# 5504   C_ID_493de71141 -11.479188  0.476581
# 2351   C_ID_da19d1dac9 -13.986524  0.474941
# 21882  C_ID_84e90acaf9 -16.833353  0.474120
# 6053   C_ID_65a0e440f8 -13.111462  0.473479
# 10954  C_ID_761c27a0f2 -16.321601  0.469192
# 13557  C_ID_3b5972c942 -14.556271  0.468167
# 8242   C_ID_d706b6696a -17.419676  0.467039
# 12708  C_ID_77cafbf835 -16.186305  0.465425
# 21809  C_ID_0c22eb865e -16.864624  0.462078
# 19530  C_ID_7c382e6fde -12.663061  0.460625
# 15994  C_ID_aeedecc9ae -17.004338  0.458634
# 3494   C_ID_1c86db6e57 -17.425766  0.458091
# 1000   C_ID_be92f84f5c -19.326652  0.457045
# 16778  C_ID_c153fbd69e -17.441705  0.454125
# 16249  C_ID_bced41d837 -16.211375  0.454118
# 14474  C_ID_464246c0a5 -15.727150  0.451211
# 18378  C_ID_a45d2e9338 -16.033292  0.447117
# 7710   C_ID_d8f884e305 -12.275787  0.446014
# 10442  C_ID_153c57fd2e -12.893855  0.444950
# 1395   C_ID_fc54efbb79 -14.130298  0.442075
# 18250  C_ID_0203943aba  -9.398047  0.439327
# 13301  C_ID_0bcfec9f5c -15.956880  0.437928
# 16394  C_ID_3ba4759657 -15.383563  0.434020
# 13209  C_ID_7d3b40444e -14.855294  0.432180
# 11505  C_ID_944c62886f -18.746963  0.431698
# 5618   C_ID_e7f772dfc0 -21.853729  0.430823
# 3225   C_ID_9c760806b5 -17.458043  0.429975
# 15516  C_ID_57356326f4  -8.668523  0.429735
# 8625   C_ID_dc60219f6c -17.610340  0.426640
# 13901  C_ID_82561a6c83 -12.581450  0.426350

# %%
eda_most_like['target'] = eda_most_like.apply(lambda x: -32  if x.prob>=0.5 else x.target,axis=1)

# %%
eda_most_like.head(50)
# Out:
#                card_id     target      prob
# 15653  C_ID_922f9c5ea6 -32.000000  0.663129
# 20967  C_ID_877b879853 -32.000000  0.631387
# 11831  C_ID_a4dfae60b0 -32.000000  0.573193
# 4119   C_ID_aae50409e7 -32.000000  0.550545
# 9772   C_ID_eff57c75a3 -32.000000  0.549016
# 6507   C_ID_ac114ef831 -32.000000  0.547913
# 14202  C_ID_833aa2f7af -32.000000  0.543521
# 15233  C_ID_1afd4a6a1f -32.000000  0.535378
# 21229  C_ID_86ddafb51c -32.000000  0.534246
# 22464  C_ID_601974ff16 -32.000000  0.525648
# 529    C_ID_1edbae8171 -32.000000  0.523336
# 1532   C_ID_a74b12dcf8 -32.000000  0.519379
# 15630  C_ID_6ab591cf62 -32.000000  0.518585
# 5482   C_ID_7f5f950342 -32.000000  0.507279
# 5394   C_ID_e7c702e96f -16.308089  0.490761
# 3724   C_ID_f06cab397a -14.232203  0.488978
# 18762  C_ID_efbf650295 -16.853801  0.486748
# 23090  C_ID_e54aeb08f7 -22.065716  0.484745
# 13009  C_ID_3ad8cfa863 -16.478209  0.481029
# 23398  C_ID_099d9774e2 -19.690900  0.478617
# 5504   C_ID_493de71141 -11.479188  0.476581
# 2351   C_ID_da19d1dac9 -13.986524  0.474941
# 21882  C_ID_84e90acaf9 -16.833353  0.474120
# 6053   C_ID_65a0e440f8 -13.111462  0.473479
# 10954  C_ID_761c27a0f2 -16.321601  0.469192
# 13557  C_ID_3b5972c942 -14.556271  0.468167
# 8242   C_ID_d706b6696a -17.419676  0.467039
# 12708  C_ID_77cafbf835 -16.186305  0.465425
# 21809  C_ID_0c22eb865e -16.864624  0.462078
# 19530  C_ID_7c382e6fde -12.663061  0.460625
# 15994  C_ID_aeedecc9ae -17.004338  0.458634
# 3494   C_ID_1c86db6e57 -17.425766  0.458091
# 1000   C_ID_be92f84f5c -19.326652  0.457045
# 16778  C_ID_c153fbd69e -17.441705  0.454125
# 16249  C_ID_bced41d837 -16.211375  0.454118
# 14474  C_ID_464246c0a5 -15.727150  0.451211
# 18378  C_ID_a45d2e9338 -16.033292  0.447117
# 7710   C_ID_d8f884e305 -12.275787  0.446014
# 10442  C_ID_153c57fd2e -12.893855  0.444950
# 1395   C_ID_fc54efbb79 -14.130298  0.442075
# 18250  C_ID_0203943aba  -9.398047  0.439327
# 13301  C_ID_0bcfec9f5c -15.956880  0.437928
# 16394  C_ID_3ba4759657 -15.383563  0.434020
# 13209  C_ID_7d3b40444e -14.855294  0.432180
# 11505  C_ID_944c62886f -18.746963  0.431698
# 5618   C_ID_e7f772dfc0 -21.853729  0.430823
# 3225   C_ID_9c760806b5 -17.458043  0.429975
# 15516  C_ID_57356326f4  -8.668523  0.429735
# 8625   C_ID_dc60219f6c -17.610340  0.426640
# 13901  C_ID_82561a6c83 -12.581450  0.426350

# %%
most_likely_liers =  eda_most_like[['card_id','target']]

# %%
most_likely_liers.head(50)
# Out:
#                card_id     target
# 31493  C_ID_922f9c5ea6 -32.000000
# 41939  C_ID_877b879853 -32.000000
# 23861  C_ID_a4dfae60b0 -32.000000
# 8339   C_ID_aae50409e7 -32.000000
# 19734  C_ID_eff57c75a3 -32.000000
# 13117  C_ID_ac114ef831 -32.000000
# 28580  C_ID_833aa2f7af -32.000000
# 30638  C_ID_1afd4a6a1f -32.000000
# 42408  C_ID_86ddafb51c -32.000000
# 44839  C_ID_601974ff16 -32.000000
# 1099   C_ID_1edbae8171 -32.000000
# 3143   C_ID_a74b12dcf8 -32.000000
# 31441  C_ID_6ab591cf62 -32.000000
# 11068  C_ID_7f5f950342 -32.000000
# 10880  C_ID_e7c702e96f -16.308089
# 7506   C_ID_f06cab397a -14.232203
# 37617  C_ID_efbf650295 -16.853801
# 46103  C_ID_e54aeb08f7 -22.065716
# 26214  C_ID_3ad8cfa863 -16.478209
# 46748  C_ID_099d9774e2 -19.690900
# 11119  C_ID_493de71141 -11.479188
# 4763   C_ID_da19d1dac9 -13.986524
# 43643  C_ID_84e90acaf9 -16.833353
# 12244  C_ID_65a0e440f8 -13.111462
# 22074  C_ID_761c27a0f2 -16.321601
# 27306  C_ID_3b5972c942 -14.556271
# 16589  C_ID_d706b6696a -17.419676
# 25655  C_ID_77cafbf835 -16.186305
# 43497  C_ID_0c22eb865e -16.864624
# 39149  C_ID_7c382e6fde -12.663061
# 32132  C_ID_aeedecc9ae -17.004338
# 7059   C_ID_1c86db6e57 -17.425766
# 2036   C_ID_be92f84f5c -19.326652
# 33691  C_ID_c153fbd69e -17.441705
# 32638  C_ID_bced41d837 -16.211375
# 29133  C_ID_464246c0a5 -15.727150
# 36829  C_ID_a45d2e9338 -16.033292
# 15501  C_ID_d8f884e305 -12.275787
# 21056  C_ID_153c57fd2e -12.893855
# 2846   C_ID_fc54efbb79 -14.130298
# 36591  C_ID_0203943aba  -9.398047
# 26792  C_ID_0bcfec9f5c -15.956880
# 32943  C_ID_3ba4759657 -15.383563
# 26597  C_ID_7d3b40444e -14.855294
# 23196  C_ID_944c62886f -18.746963
# 11361  C_ID_e7f772dfc0 -21.853729
# 6486   C_ID_9c760806b5 -17.458043
# 31202  C_ID_57356326f4  -8.668523
# 17393  C_ID_dc60219f6c -17.610340
# 27965  C_ID_82561a6c83 -12.581450

# %%
for card_id in tqdm.tqdm(most_likely_liers['card_id']):
    best_without_outlier_sub.loc[best_without_outlier_sub['card_id']==card_id,'target']\
    = most_likely_liers.loc[most_likely_liers['card_id']==card_id,'target'].values
# Out:
# 100%|██████████| 50000/50000 [09:49<00:00, 84.80it/s]

# %%
best_without_outlier_sub.to_csv("combining_submission.csv", index=False)

# %%
best_submission.target.mean()
# Out:
# -0.39410874576699123

# %%
best_without_outlier_sub.target.mean()
# Out:
# -0.3908287056899514
